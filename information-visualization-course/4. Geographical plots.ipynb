# %% [markdown]
# ## Geographical plots

# %% [markdown]
# In this part of the hands-on we will be plotting information on geographical. This goes by the name of Geographic Information Systems (GIS), which, as the name implies, is some sort of information visualization.
#
# GIS comes in many forms but for this example we will be making a **Choropleth**. A Choropleth is a map visualisation where parts of a map are shaded in proportion to a data measurement or statistical value of choice.
#
# For this example we are going to visualise the results of the general election of 2023 for each municipality in the Netherlands. For this we will first need to import Pandas and prepare our data.

# %%
# %reset -f

import pandas

# Load the data with a semi-colon delimiter which is used in the csv file
results = pandas.read_csv('./data/geographical/TK2023_results.csv', delimiter=';')

# Reformat the dataframe so that every political party is a separate column and every row is a unique municipality entry 
results = results.groupby(['municipality','type'])['value'].sum().unstack(level=1).reset_index()

# Create a party columns only dataframe
party_df = results.drop(columns=['municipality', 'AantalBlancoStemmen', 'AantalGeldigeStemmen', 'AantalOngeldigeStemmen', 'Kiesgerechtigden', 'Opkomst'])

# Change the number of votes for a party to the total percentage voted for that party
party_information = {f'p_{party_name}': 100.0 * party_df[party_name] / results['AantalGeldigeStemmen'] for party_name in party_df.columns}

# All columns with the general voter information
voters_information = {'municipality': results['municipality'], 
                      'p_turnout': 100.0 * results['Opkomst'] / results['Kiesgerechtigden'],
                      'p_valid': 100.0 * results['AantalGeldigeStemmen'] / results['Opkomst'],
                      'p_invalid': 100.0 * results['AantalOngeldigeStemmen'] / results['Opkomst'],
                      'p_blank': 100.0 * results['AantalBlancoStemmen'] / results['AantalGeldigeStemmen']}

# Combine all the data columns
p_results = pandas.DataFrame(dict(voters_information, **party_information))

# Replace all NaN with zero
p_results = p_results.fillna(0) 

p_results
# Out:
#          municipality  p_turnout    p_valid  p_invalid   p_blank  p_50PLUS  \
# 0       's-Gravenhage  68.799740  99.352523   0.419864  0.229096  0.381281
# 1    's-Hertogenbosch  78.048583  99.620574   0.183996  0.196175  0.523828
# 2         Aa en Hunze  85.084762  99.698627   0.117201  0.184729  0.335871
# 3            Aalsmeer  82.894236  99.668401   0.178553  0.153555  0.588627
# 4              Aalten  82.456873  99.803161   0.089984  0.107066  0.349375
# ..                ...        ...        ...        ...       ...       ...
# 338           Zundert  80.012650  99.698167   0.114984  0.187414  0.634326
# 339           Zutphen  79.927054  99.633653   0.157465  0.209650  0.358018
# 340   Zwartewaterland  87.726159  99.813718   0.119753  0.066653  0.226621
# 341       Zwijndrecht  73.288049  99.588070   0.217848  0.194885  0.628406
# 342            Zwolle  81.204306  99.557693   0.219945  0.223350  0.348377
#
#          p_BBB    p_BIJ1  p_BVNL / Groep Van Haga     p_CDA  ...  \
# 0     1.287438  0.827200                 0.405418  1.917861  ...
# 1     2.002442  0.350610                 0.429915  2.587835  ...
# 2     9.577922  0.117555                 0.475817  2.485446  ...
# 3     3.383324  0.261043                 0.578390  3.695552  ...
# 4    15.575341  0.101431                 0.569142  7.150907  ...
# ..         ...       ...                      ...       ...  ...
# 338  10.898868  0.100915                 0.598284  3.928494  ...
# 339   4.938073  0.229003                 0.432202  2.299703  ...
# 340   7.978404  0.033327                 0.426581  4.992335  ...
# 341   2.282942  0.262499                 0.342044  3.913614  ...
# 342   3.238572  0.426064                 0.426064  3.163312  ...
#
#      p_Partij voor de Dieren  p_PartijvdSport  p_Piratenpartij - De Groenen  \
# 0                   3.387348         0.000000                      0.116594
# 1                   2.458443         0.038609                      0.092870
# 2                   2.507837         0.000000                      0.089566
# 3                   1.648155         0.071659                      0.071659
# 4                   1.200270         0.000000                      0.067621
# ..                       ...              ...                           ...
# 338                 1.290276         0.043249                      0.028833
# 339                 4.186557         0.000000                      0.103212
# 340                 0.733187         0.013331                      0.033327
# 341                 1.571014         0.083522                      0.059659
# 342                 2.950887         0.080115                      0.098322
#
#      p_Politieke Partij voor Basisinkomen  p_SP (Socialistische Partij)  \
# 0                                0.031092                      2.641559
# 1                                0.013565                      4.229232
# 2                                0.000000                      3.493059
# 3                                0.000000                      1.991094
# 4                                0.000000                      2.744280
# ..                                    ...                           ...
# 338                              0.014416                      3.481583
# 339                              0.000000                      4.880015
# 340                              0.000000                      1.626341
# 341                              0.000000                      2.986915
# 342                              0.000000                      3.089267
#
#      p_Samen voor Nederland  p_Splinter  \
# 0                  0.042137    0.146867
# 1                  0.042783    0.125218
# 2                  0.083968    0.078370
# 3                  0.030711    0.194503
# 4                  0.236673    0.101431
# ..                      ...         ...
# 338                0.028833    0.108124
# 339                0.067733    0.116114
# 340                0.019996    0.013331
# 341                0.083522    0.119318
# 342                0.041271    0.117744
#
#      p_Staatkundig Gereformeerde Partij (SGP)      p_VVD    p_Volt
# 0                                    0.378418  15.115428  2.275005
# 1                                    0.117913  17.569105  2.394791
# 2                                    0.240708  16.222571  1.371473
# 3                                    0.644930  25.070379  1.330808
# 4                                    0.642398  11.574439  0.766370
# ..                                        ...        ...       ...
# 338                                  0.100915  20.471419  1.066820
# 339                                  0.351568  11.759773  1.793317
# 340                                 20.662534   7.631807  0.479904
# 341                                  4.271567  14.851052  0.727837
# 342                                  1.160448  12.774635  2.217717
#
# [343 rows x 31 columns]

# %% [markdown]
# As you can see we now prepared our data and created a DataFrame that consists of the blank votes, invalid votes, valid votes, turnout and all parties in percentages. This way we can easily color code the municipalities and compare them to each other based on the data columns in the DataFrame.
#
# Now lets create the map. The first map we will create will be a choropleth displaying the 2023 general elections turnout per municipality.

# %%
from IPython.display import display, IFrame
import folium

geo_path = r'./data/geographical/gemeentegrenzen.geojson'

ref_map = folium.Map(
    location=[52.239177, 5.327108], # This will center the view on the world map where the Netherlands is located
    tiles="cartodbpositron",          # This creates a base map from  which is less distracting than the default Openstreetmap map
    zoom_start=8)                   # This will zoom in on the center of view to get the Netherlands in full frame

folium.Choropleth(
    # This is the path to the geojson file that contains all the municipality shapes and locations             
    geo_data=geo_path,                     
    # We will use the percentage dataframe for the choropleth mapping          
    data=p_results,                        
    # Municipality will be used for the mapping key and p_turnout for its value
    columns=['municipality', 'p_turnout'], 
    # Use statnaam (this is the key in the geojson file that has the municipality name) as keys for colormapping 
    key_on='feature.properties.statnaam',   
    # We are going to use a color map from yellow to green
    fill_color='YlGn',                     
    # This gives municipality shapes some opacity so that we can still see the background
    fill_opacity=0.7,                      
    # This gives the lines around the municipality shapes some opacity so that they don't stand out too much
    line_opacity=0.2,                      
    # The legend
    legend_name='Turn out (%)').add_to(ref_map)            

ref_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acc45964bdfadcc5dd84cbc6be945168 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acc45964bdfadcc5dd84cbc6be945168&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acc45964bdfadcc5dd84cbc6be945168 = L.map(
#                 &quot;map_acc45964bdfadcc5dd84cbc6be945168&quot;,
#                 {
#                     center: [52.239177, 5.327108],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab37fd08ea533547f35147c410562cab = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ab37fd08ea533547f35147c410562cab.addTo(map_acc45964bdfadcc5dd84cbc6be945168);
#
#
#             var choropleth_eb510f13f2023f44e8ba4ddaf2763f46 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_a3e4c11471a97e16d08753c99e9fe1cc_styler(feature) {
#             switch(feature.id) {
#                 case &quot;gemeente_gegeneraliseerd.9d998617-2299-4709-bd54-e280fab82777&quot;: case &quot;gemeente_gegeneraliseerd.07611fe8-cd79-462f-a24d-98758dd35c99&quot;: case &quot;gemeente_gegeneraliseerd.f26c884d-9e3d-41d5-801b-b220448cc493&quot;: case &quot;gemeente_gegeneraliseerd.25a1dc7f-3360-41e5-9268-2a2ad98420c2&quot;: case &quot;gemeente_gegeneraliseerd.d69dceee-b1d9-4a24-b0f6-1db7c5cdf372&quot;: case &quot;gemeente_gegeneraliseerd.8555527e-2898-4306-ad66-31a9e8782fe9&quot;: case &quot;gemeente_gegeneraliseerd.7aa17e38-e444-4a27-a2c5-ff072803542c&quot;: case &quot;gemeente_gegeneraliseerd.98259971-48e1-4850-b881-8b415e49ace5&quot;: case &quot;gemeente_gegeneraliseerd.c8441d33-d2ac-48a8-a635-9dc317ccc7a2&quot;: case &quot;gemeente_gegeneraliseerd.bccb4058-5915-4084-a52b-740543318a2e&quot;: case &quot;gemeente_gegeneraliseerd.5322115d-f7cf-4d91-8baa-4c1d56a33714&quot;: case &quot;gemeente_gegeneraliseerd.0e8a2083-dd43-47e2-9eeb-cb19790c3c4f&quot;: case &quot;gemeente_gegeneraliseerd.2ce58559-25e2-4397-84c7-b684bf00e3bb&quot;: case &quot;gemeente_gegeneraliseerd.5df7fcf3-aab5-4e7d-b1bf-a31424dbe726&quot;: case &quot;gemeente_gegeneraliseerd.9ad61f12-c6e9-47fa-b531-0926ea60d1d8&quot;: case &quot;gemeente_gegeneraliseerd.1a1a755d-9065-44d7-a463-ece4d8f0a8d2&quot;: case &quot;gemeente_gegeneraliseerd.cf68214d-5023-4b56-a8bf-5fb4324647f2&quot;: case &quot;gemeente_gegeneraliseerd.bd0f038b-69e7-47fe-93b7-016b59418cf5&quot;: case &quot;gemeente_gegeneraliseerd.8acd6111-c056-49ba-81a9-f72dc698c1d0&quot;: case &quot;gemeente_gegeneraliseerd.200acf45-5e29-4b5d-980c-22fa78063710&quot;: case &quot;gemeente_gegeneraliseerd.71e7f0ea-65c7-4fce-8453-e701562082e9&quot;: case &quot;gemeente_gegeneraliseerd.c13e25ff-db07-4867-a874-8c1b6dd1090b&quot;: case &quot;gemeente_gegeneraliseerd.a1678f5e-3df5-4762-b8d0-54e0341c15bf&quot;: case &quot;gemeente_gegeneraliseerd.37014fe5-e3a2-482b-92d4-92e5a6311b2d&quot;: case &quot;gemeente_gegeneraliseerd.5de299c8-aeb3-405f-b487-be27f3c7a141&quot;: case &quot;gemeente_gegeneraliseerd.e4fd8cc3-ade9-47d4-bf16-ab54de20a3d0&quot;: case &quot;gemeente_gegeneraliseerd.89b8aa1b-63bf-482d-809d-3aa5bf1f99b0&quot;: case &quot;gemeente_gegeneraliseerd.702e994c-f2a4-47bb-b235-e13d3694e4cb&quot;: case &quot;gemeente_gegeneraliseerd.8ab7f23f-950f-4164-97fb-d54f05c07010&quot;: case &quot;gemeente_gegeneraliseerd.5b909fe1-7fae-4f5a-8ae4-504c6a0ad576&quot;: case &quot;gemeente_gegeneraliseerd.e4f0030a-c839-43fd-a53d-6e393bf827e0&quot;: case &quot;gemeente_gegeneraliseerd.d272aec2-e76a-4d43-9cb7-c398ce084357&quot;: case &quot;gemeente_gegeneraliseerd.5426e6b9-4c50-41bc-9936-b91f3cd58ebc&quot;: case &quot;gemeente_gegeneraliseerd.8ede58be-1ce9-4c47-a2a1-8f77ed80b056&quot;: case &quot;gemeente_gegeneraliseerd.2717c342-2dd1-4831-9c06-c6c0deb78c5e&quot;: case &quot;gemeente_gegeneraliseerd.1e5908d9-0ceb-46b5-bd4e-1b4ad66c3d98&quot;: case &quot;gemeente_gegeneraliseerd.6dc5b099-f988-4787-adb0-68b487a67de1&quot;: case &quot;gemeente_gegeneraliseerd.f55d412a-15b3-4085-a276-e863a6433837&quot;: case &quot;gemeente_gegeneraliseerd.cfe8619a-86ed-4eee-a5eb-35244851fc52&quot;: case &quot;gemeente_gegeneraliseerd.78d502f9-f883-484b-a426-740d493e3dc4&quot;: case &quot;gemeente_gegeneraliseerd.42d2e464-b777-4a13-aaee-5bbdfd1016e4&quot;: case &quot;gemeente_gegeneraliseerd.e96203e4-37dc-4ffc-ad43-ce68672b8318&quot;: case &quot;gemeente_gegeneraliseerd.45d0a108-0e87-46d4-96f9-d1937defc759&quot;: case &quot;gemeente_gegeneraliseerd.b6835de0-076c-412d-a279-f64e4071f8f4&quot;: case &quot;gemeente_gegeneraliseerd.cf938213-8e81-4053-aa46-359ef4eda8bc&quot;: case &quot;gemeente_gegeneraliseerd.067086ce-7373-452a-8380-0fd3706609b1&quot;: ca

# %% [markdown]
# If everything went according to plan you should see a map of the Netherlands with patches shaded green propotional to the *p_turnout* data values. From this choropleth you can already see that the percentage of turn out is relatively lower in and around the bigger cities.
#
# * * *
# * * *
#
# #### Exercise
#
# For this exercise you are going to look at how the other data columns are represented across the Netherlands by changing the **columns** variable second entry, in the **folium.Choropleth** function below, to one of the other data columns in our DataFrame. Also try to represent the results with the right color map (in personal preferences of course), from purple to blue (PuBu), from yellow to green (YlGn) or from orange to red (OrRd).

# %%
colorMaps = ['PuBu', 'YlGn', 'OrRd']

geo_path = r'./data/geographical/gemeentegrenzen.geojson'

ref_map = folium.Map(
    location=[52.139177, 5.327108], # This will center the view on the world map where the Netherlands is located
    tiles="cartodbpositron",          # This creates a base map from  which is less distracting than the default Openstreetmap map
    zoom_start=8)                   # This will zoom in on the center of view to get the Netherlands in full frame

folium.Choropleth(
    # This is the path to the geojson file that contains all the municipality shapes and locations      
    geo_data=geo_path,                     
    # We will use the percentage dataframe for the choropleth mapping      
    data=p_results,                       
    # Municipality will be used for the mapping key and one of the other datacolumns as a value     
    columns=['municipality', 'p_50PLUS'],  
    # Use statnaam as keys for colormapping   
    key_on='feature.properties.statnaam',   
    # We are going to use a color map stored in the colormap dictionary
    fill_color=colorMaps[2],      
    # This gives municipality shapes some opacity so that we can still see the background       
    fill_opacity=0.7,                      
    # This gives the lines around the municipality shapes some opacity so that they don't stand out too much     
    line_opacity=0.2,                 
    # The legend
    legend_name='p_50PLUS description').add_to(ref_map)

ref_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d12d0d7ca8f835de015a46de39f9725 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d12d0d7ca8f835de015a46de39f9725&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d12d0d7ca8f835de015a46de39f9725 = L.map(
#                 &quot;map_6d12d0d7ca8f835de015a46de39f9725&quot;,
#                 {
#                     center: [52.139177, 5.327108],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14ea62a71e9f0a664ca45ce81c58ed19 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_14ea62a71e9f0a664ca45ce81c58ed19.addTo(map_6d12d0d7ca8f835de015a46de39f9725);
#
#
#             var choropleth_50a42f62a731912c6deb378b441fbe53 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_ac4312f462f6c53153549f788554d57a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;gemeente_gegeneraliseerd.9d998617-2299-4709-bd54-e280fab82777&quot;: case &quot;gemeente_gegeneraliseerd.25a1dc7f-3360-41e5-9268-2a2ad98420c2&quot;: case &quot;gemeente_gegeneraliseerd.0e8a2083-dd43-47e2-9eeb-cb19790c3c4f&quot;: case &quot;gemeente_gegeneraliseerd.c4862076-453f-48c1-9f5e-d1d012dfd05e&quot;: case &quot;gemeente_gegeneraliseerd.1a1a755d-9065-44d7-a463-ece4d8f0a8d2&quot;: case &quot;gemeente_gegeneraliseerd.b541792a-437a-4540-a613-ffcd78607ff0&quot;: case &quot;gemeente_gegeneraliseerd.92307690-0bb0-431d-8de1-d22e63841b46&quot;: case &quot;gemeente_gegeneraliseerd.cf68214d-5023-4b56-a8bf-5fb4324647f2&quot;: case &quot;gemeente_gegeneraliseerd.fd32ca3b-46ba-4de4-9e87-42ffcd51ca59&quot;: case &quot;gemeente_gegeneraliseerd.e780f1c1-1ef9-4212-b472-0fa886e0f554&quot;: case &quot;gemeente_gegeneraliseerd.391d3a2d-f456-4094-94c0-99e147b25678&quot;: case &quot;gemeente_gegeneraliseerd.498a218d-f909-4083-b172-fc416e49608e&quot;: case &quot;gemeente_gegeneraliseerd.99a9c152-2e4f-4e4b-8f9b-069390680fea&quot;: case &quot;gemeente_gegeneraliseerd.14f77a8c-7eee-4d43-8133-641c6d0e438b&quot;: case &quot;gemeente_gegeneraliseerd.8acd6111-c056-49ba-81a9-f72dc698c1d0&quot;: case &quot;gemeente_gegeneraliseerd.1a5432cf-67d2-4ed0-ac30-3d3c4e67b9fc&quot;: case &quot;gemeente_gegeneraliseerd.4f1bf1de-e586-4b8f-9385-943dca1c5586&quot;: case &quot;gemeente_gegeneraliseerd.a1678f5e-3df5-4762-b8d0-54e0341c15bf&quot;: case &quot;gemeente_gegeneraliseerd.b48283b2-0112-4a28-993a-15137c12e811&quot;: case &quot;gemeente_gegeneraliseerd.02dd48f8-e0a0-4b8a-b8b7-71ec0a282261&quot;: case &quot;gemeente_gegeneraliseerd.b23c0ed3-6442-48d7-9709-f4fa6a5bf4e6&quot;: case &quot;gemeente_gegeneraliseerd.d5dc1568-2e59-4548-88ae-55d8ef89b201&quot;: case &quot;gemeente_gegeneraliseerd.702e994c-f2a4-47bb-b235-e13d3694e4cb&quot;: case &quot;gemeente_gegeneraliseerd.ba8ef4f0-4479-4818-a937-2cd63e38cd03&quot;: case &quot;gemeente_gegeneraliseerd.1dce0aa5-523e-428d-bff1-4f579c605f8c&quot;: case &quot;gemeente_gegeneraliseerd.4b80fec7-ec97-42ab-9988-9c8c840b6c40&quot;: case &quot;gemeente_gegeneraliseerd.a8795435-75fb-4332-ac95-37d7b4e0f319&quot;: case &quot;gemeente_gegeneraliseerd.d272aec2-e76a-4d43-9cb7-c398ce084357&quot;: case &quot;gemeente_gegeneraliseerd.933039ef-339c-4700-9c12-060540f92c44&quot;: case &quot;gemeente_gegeneraliseerd.f55d412a-15b3-4085-a276-e863a6433837&quot;: case &quot;gemeente_gegeneraliseerd.42d2e464-b777-4a13-aaee-5bbdfd1016e4&quot;: case &quot;gemeente_gegeneraliseerd.2fdb80c1-1cfa-4e5e-8600-58af9f93a701&quot;: case &quot;gemeente_gegeneraliseerd.1ab6ca51-69ca-4d08-9aea-c82969e34e72&quot;: case &quot;gemeente_gegeneraliseerd.6855d3bb-150a-4783-9a55-e20281800677&quot;: case &quot;gemeente_gegeneraliseerd.e559d0d6-f8bf-4844-ab6d-fcf9bbad56fa&quot;: case &quot;gemeente_gegeneraliseerd.5bc1fe7e-bc8f-48aa-a5b1-01af95ecdc4b&quot;: case &quot;gemeente_gegeneraliseerd.67f66c97-bcac-4d0a-bece-6cd698c7e3b0&quot;: case &quot;gemeente_gegeneraliseerd.78c33e7f-6d61-44cb-a602-85f570d8108e&quot;: case &quot;gemeente_gegeneraliseerd.0f09897f-3474-45a7-bca3-557095cd23b5&quot;: case &quot;gemeente_gegeneraliseerd.bc56d274-4afe-4809-b142-344a6eec334a&quot;: case &quot;gemeente_gegeneraliseerd.3b35e18d-c211-4e22-9c9c-b29fc1aad39b&quot;: case &quot;gemeente_gegeneraliseerd.b3a22887-5c21-463d-8412-fc5a25b4b789&quot;: case &quot;gemeente_gegeneraliseerd.08ad636f-a2be-446f-9f8f-03fb439230fd&quot;: case &quot;gemeente_gegeneraliseerd.3ef56981-81c4-4926-8b88-7242ac930be9&quot;: case &quot;gemeente_gegeneraliseerd.edf25e6c-64c3-47a8-a78c-1b1f7642129e&quot;: case &quot;gemeente_gegeneraliseerd.f161fb5f-dfa4-4c55-a980-ce0e27a16194&quot;: ca

# %% [markdown]
# ***
# ***

# %% [markdown]
# This chapter concludes the main visualation chapters of this course now you may proceed the conclusion notebook of this course for some take away messages: [Conclusion](./5.&#32;Conclusion.ipynb)
